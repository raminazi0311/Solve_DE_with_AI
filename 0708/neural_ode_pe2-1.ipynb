# %% [markdown]
# # Neural ODE

# %%
import jax
import jax.numpy as jnp
import jax.random as jr
from jax import vmap
import optax
import equinox as eqx
import diffrax
import jax.nn as jnn
import matplotlib.pyplot as plt
import time
from datetime import datetime

# %%
def get_data(ts, y0):
    def beta(t):
        beta = lambda t: 0.025 * jnp.sin(2 * jnp.pi * t / 20) + 0.03
        return beta(t)

    def alpha(t):
        return 0.2

    def f(t, y, args=None):
        bb = beta(t)
        aa = alpha(t)
        S, I = y
        return jnp.array([-bb * S * I, bb * S * I - aa * I])

    sol = diffrax.diffeqsolve(
        diffrax.ODETerm(f),
        diffrax.Tsit5(),
        t0=0,
        t1=ts[-1],
        dt0=0.1,
        y0=y0,
        saveat=diffrax.SaveAt(ts=ts)
    )
    return ts, sol.ys


def relative_error(pred, true):
    return jnp.linalg.norm(pred - true, 2) / jnp.linalg.norm(true, 2)

# %%
class Func(eqx.Module):
    NN: eqx.nn.MLP

    def __init__(self, width_size, depth, *, key):
        self.NN = eqx.nn.MLP(2, 2, width_size, depth, activation=jnn.tanh, key=key)

    def __call__(self, t, y, arg=None):
        return self.NN(y)


class NeuralODE(eqx.Module):
    func: Func
    alpha: jnp.ndarray
    beta: eqx.nn.MLP

    def __init__(self, width_size, depth, *, key):
        key_func, key_alpha, key_beta = jr.split(key, 3)
        self.func = Func(width_size, depth, key=key_func)
        self.alpha = jnp.array(jr.uniform(key_alpha, (), minval=0.0, maxval=1.0))
        self.beta = eqx.nn.MLP(1,
            1,
            width_size,
            depth,
            activation=jnn.softplus,
            final_activation=lambda x: 0.1 * jnn.sigmoid(x),
            key=key_beta
            )

    def __call__(self, ts, y0):
        solution = diffrax.diffeqsolve(
            diffrax.ODETerm(self.func),
            diffrax.Tsit5(),
            t0=0,
            t1=ts[-1],
            dt0=0.01,
            y0=y0,
            stepsize_controller=diffrax.PIDController(rtol=1e-3, atol=1e-6),
            saveat=diffrax.SaveAt(ts=ts),
        )
        return self.alpha, self.beta, solution.ys

# %%
def main(
    lr=1e-3,
    t_data=jnp.linspace(0., 20., 20),
    t_ge=jnp.linspace(0., 20., 200),
    width_size=64,
    depth=2,
    seed=5678,
    steps=1000,
):
    key = jr.PRNGKey(seed)

    y0 = jnp.array([100.0, 1.0])
    t_data, y_data = get_data(t_data, y0)
    t_ge, y_ge = get_data(t_ge, y0)

    model = NeuralODE(width_size, depth, key=key)
    scheduler = optax.piecewise_constant_schedule(
        init_value=lr,
        boundaries_and_scales={10000: 0.1}
    )
    optim = optax.adam(learning_rate=scheduler)

    @eqx.filter_value_and_grad
    def grad_loss(model):
        _, _, pred_data = model(t_data, y0)
        data_loss = jnp.mean((pred_data - y_data) ** 2)

        pred_alpha, _, pred_ge = model(t_ge, y0)
        pred_beta=vmap(lambda t: model.beta(jnp.array([t])))(t_ge)
        pred_beta=jnp.squeeze(pred_beta)
        dydt = vmap(lambda y: model.func(t_ge, y))(pred_ge)
        dS = - pred_beta * pred_ge[:,0] * pred_ge[:,1]
        dI = pred_beta * pred_ge[:,0] * pred_ge[:,1] - pred_alpha * pred_ge[:,1]
        dSI = jnp.stack([dS, dI], axis=-1)
        ge_loss = jnp.mean((dydt - dSI) ** 2)
        return data_loss+ge_loss



    @eqx.filter_jit
    def make_step(model, opt_state):
        loss, grads = grad_loss(model)
        updates, opt_state = optim.update(grads, opt_state, value=loss)
        model = eqx.apply_updates(model, updates)
        return loss, model, opt_state

    opt_state = optim.init(eqx.filter(model, eqx.is_inexact_array))
    loss_list = []
    alpha_list = []

    for step in range(steps):
        loss, model, opt_state = make_step(model, opt_state)
        loss_list.append(loss)
        alpha_list.append(float(model.alpha))

        if step % 100 == 0 or step == steps - 1:
            print(f"Step {step}, Loss: {loss:.4e}")

    return t_data, y_data, t_ge, y_ge, model, loss_list, alpha_list

# %%
t_data, y_data, t_ge, y_ge, model, loss_list, alpha_list = main(steps=20000)
# Out:
# Step 0, Loss: 5.5819e+03
# Step 100, Loss: 1.0565e+03
# Step 200, Loss: 6.8787e+02
# Step 300, Loss: 5.0442e+02
# Step 400, Loss: 3.8640e+02
# Step 500, Loss: 3.0328e+02
# Step 600, Loss: 2.4526e+02
# Step 700, Loss: 2.0218e+02
# Step 800, Loss: 1.7068e+02
# Step 900, Loss: 1.4473e+02
# Step 1000, Loss: 1.2334e+02
# Step 1100, Loss: 1.0585e+02
# Step 1200, Loss: 9.1472e+01
# Step 1300, Loss: 8.0057e+01
# Step 1400, Loss: 7.1021e+01
# Step 1500, Loss: 6.3095e+01
# Step 1600, Loss: 5.6657e+01
# Step 1700, Loss: 5.1179e+01
# Step 1800, Loss: 4.6343e+01
# Step 1900, Loss: 4.2363e+01
# Step 2000, Loss: 3.9355e+01
# Step 2100, Loss: 3.6082e+01
# Step 2200, Loss: 3.3800e+01
# Step 2300, Loss: 3.1781e+01
# Step 2400, Loss: 3.0377e+01
# Step 2500, Loss: 2.8615e+01
# Step 2600, Loss: 2.8202e+01
# Step 2700, Loss: 2.6723e+01
# Step 2800, Loss: 2.6277e+01
# Step 2900, Loss: 2.5776e+01
# Step 3000, Loss: 2.5038e+01
# Step 3100, Loss: 2.2436e+01
# Step 3200, Loss: 2.4363e+01
# Step 3300, Loss: 2.3973e+01
# Step 3400, Loss: 2.4013e+01
# Step 3500, Loss: 2.3447e+01
# Step 3600, Loss: 2.3463e+01
# Step 3700, Loss: 2.3391e+01
# Step 3800, Loss: 2.3289e+01
# Step 3900, Loss: 2.3040e+01
# Step 4000, Loss: 2.3134e+01
# Step 4100, Loss: 2.3370e+01
# Step 4200, Loss: 2.2998e+01
# Step 4300, Loss: 2.2990e+01
# Step 4400, Loss: 2.3121e+01
# Step 4500, Loss: 2.2699e+01
# Step 4600, Loss: 2.2843e+01
# Step 4700, Loss: 2.2908e+01
# Step 4800, Loss: 2.2335e+01
# Step 4900, Loss: 2.2893e+01
# Step 5000, Loss: 2.1657e+01
# Step 5100, Loss: 2.2063e+01
# Step 5200, Loss: 2.1851e+01
# Step 5300, Loss: 2.1749e+01
# Step 5400, Loss: 2.0945e+01
# Step 5500, Loss: 1.9951e+01
# Step 5600, Loss: 1.8128e+01
# Step 5700, Loss: 1.7343e+01
# Step 5800, Loss: 1.6551e+01
# Step 5900, Loss: 1.5596e+01
# Step 6000, Loss: 1.4782e+01
# Step 6100, Loss: 1.5036e+01
# Step 6200, Loss: 1.3006e+01
# Step 6300, Loss: 1.2336e+01
# Step 6400, Loss: 1.1050e+01
# Step 6500, Loss: 1.0083e+01
# Step 6600, Loss: 2.1257e+01
# Step 6700, Loss: 3.1940e+01
# Step 6800, Loss: 1.7576e+01
# Step 6900, Loss: 1.3792e+01
# Step 7000, Loss: 1.3436e+01
# Step 7100, Loss: 1.2944e+01
# Step 7200, Loss: 1.2374e+01
# Step 7300, Loss: 1.2266e+01
# Step 7400, Loss: 1.1948e+01
# Step 7500, Loss: 1.2084e+01
# Step 7600, Loss: 1.1920e+01
# Step 7700, Loss: 1.1698e+01
# Step 7800, Loss: 1.1434e+01
# Step 7900, Loss: 1.1389e+01
# Step 8000, Loss: 1.1586e+01
# Step 8100, Loss: 1.1461e+01
# Step 8200, Loss: 1.1332e+01
# Step 8300, Loss: 1.1343e+01
# Step 8400, Loss: 1.1428e+01
# Step 8500, Loss: 1.1619e+01
# Step 8600, Loss: 1.1045e+01
# Step 8700, Loss: 1.0892e+01
# Step 8800, Loss: 1.0906e+01
# Step 8900, Loss: 1.0948e+01
# Step 9000, Loss: 1.0790e+01
# Step 9100, Loss: 1.0609e+01
# Step 9200, Loss: 1.0823e+01
# Step 9300, Loss: 1.0474e+01
# Step 9400, Loss: 1.0866e+01
# Step 9500, Loss: 1.0709e+01
# Step 9600, Loss: 1.0381e+01
# Step 9700, Loss: 1.0018e+01
# Step 9800, Loss: 9.6465e+00
# Step 9900, Loss: 1.0047e+01
# Step 10000, Loss: 1.0025e+01
# Step 10100, Loss: 9.6629e+00
# Step 10200, Loss: 9.9409e+00
# Step 10300, Loss: 9.7192e+00
# Step 10400, Loss: 9.9576e+00
# Step 10500, Loss: 9.5846e+00
# Step 10600, Loss: 1.0119e+01
# Step 10700, Loss: 1.0483e+01
# Step 10800, Loss: 9.8181e+00
# Step 10900, Loss: 9.6969e+00
# Step 11000, Loss: 9.9006e+00
# Step 11100, Loss: 9.5176e+00
# Step 11200, Loss: 9.5240e+00
# Step 11300, Loss: 9.7654e+00
# Step 11400, Loss: 9.5414e+00
# Step 11500, Loss: 9.6064e+00
# Step 11600, Loss: 9.4870e+00
# Step 11700, Loss: 9.6546e+00
# Step 11800, Loss: 9.4567e+00
# Step 11900, Loss: 9.4749e+00
# Step 12000, Loss: 9.4953e+00
# Step 12100, Loss: 9.3795e+00
# Step 12200, Loss: 9.5126e+00
# Step 12300, Loss: 9.4612e+00
# Step 12400, Loss: 9.2575e+00
# Step 12500, Loss: 9.5651e+00
# Step 12600, Loss: 9.3105e+00
# Step 12700, Loss: 9.1154e+00
# Step 12800, Loss: 8.8551e+00
# Step 12900, Loss: 9.3605e+00
# Step 13000, Loss: 9.2235e+00
# Step 13100, Loss: 8.7918e+00
# Step 13200, Loss: 9.1000e+00
# Step 13300, Loss: 9.5266e+00
# Step 13400, Loss: 9.3772e+00
# Step 13500, Loss: 8.9501e+00
# Step 13600, Loss: 9.1598e+00
# Step 13700, Loss: 9.0785e+00
# Step 13800, Loss: 9.2567e+00
# Step 13900, Loss: 9.0869e+00
# Step 14000, Loss: 9.0888e+00
# Step 14100, Loss: 9.0764e+00
# Step 14200, Loss: 9.0904e+00
# Step 14300, Loss: 9.0169e+00
# Step 14400, Loss: 8.9906e+00
# Step 14500, Loss: 9.5315e+00
# Step 14600, Loss: 9.2413e+00
# Step 14700, Loss: 8.9216e+00
# Step 14800, Loss: 8.8837e+00
# Step 14900, Loss: 8.8249e+00
# Step 15000, Loss: 8.8267e+00
# Step 15100, Loss: 8.8185e+00
# Step 15200, Loss: 8.7436e+00
# Step 15300, Loss: 8.7152e+00
# Step 15400, Loss: 8.8812e+00
# Step 15500, Loss: 8.9551e+00
# Step 15600, Loss: 8.7659e+00
# Step 15700, Loss: 8.4928e+00
# Step 15800, Loss: 8.7013e+00
# Step 15900, Loss: 8.5140e+00
# Step 16000, Loss: 8.7085e+00
# Step 16100, Loss: 8.6262e+00
# Step 16200, Loss: 8.5301e+00
# Step 16300, Loss: 8.2166e+00
# Step 16400, Loss: 8.5429e+00
# Step 16500, Loss: 8.4123e+00
# Step 16600, Loss: 8.4727e+00
# Step 16700, Loss: 8.5399e+00
# Step 16800, Loss: 8.4019e+00
# Step 16900, Loss: 7.4157e+00
# Step 17000, Loss: 8.3448e+00
# Step 17100, Loss: 8.0044e+00
# Step 17200, Loss: 8.6127e+00
# Step 17300, Loss: 8.2610e+00
# Step 17400, Loss: 8.4298e+00
# Step 17500, Loss: 8.1919e+00
# Step 17600, Loss: 8.2816e+00
# Step 17700, Loss: 7.9864e+00
# Step 17800, Loss: 7.8668e+00
# Step 17900, Loss: 7.7956e+00
# Step 18000, Loss: 7.6425e+00
# Step 18100, Loss: 7.7643e+00
# Step 18200, Loss: 8.0672e+00
# Step 18300, Loss: 6.9122e+00
# Step 18400, Loss: 7.7861e+00
# Step 18500, Loss: 7.5200e+00
# Step 18600, Loss: 7.6764e+00
# Step 18700, Loss: 7.7872e+00
# Step 18800, Loss: 7.5598e+00
# Step 18900, Loss: 7.6491e+00
# Step 19000, Loss: 7.3708e+00
# Step 19100, Loss: 7.4145e+00
# Step 19200, Loss: 7.5667e+00
# Step 19300, Loss: 7.4422e+00
# Step 19400, Loss: 7.0527e+00
# Step 19500, Loss: 7.0815e+00
# Step 19600, Loss: 7.1104e+00
# Step 19700, Loss: 7.0496e+00
# Step 19800, Loss: 6.8023e+00
# Step 19900, Loss: 6.7894e+00
# Step 19999, Loss: 6.7170e+00

# %%
y0 = jnp.array([100.0, 1.0])
exact_ts, exact_ys = get_data(jnp.linspace(0, 20, 1000), y0)

eval_alpha, eval_beta, model_ys = model(exact_ts, y0)

rel_S = relative_error(model_ys[:, 0], exact_ys[:, 0])
rel_I = relative_error(model_ys[:, 1], exact_ys[:, 1])

fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].plot(exact_ts, exact_ys[:, 0], label="True S")
axs[0].plot(exact_ts, model_ys[:, 0], label="Pred S", linestyle="--")
# axs[0].plot(t_ge, y_ge[:, 0], label="ge S", linestyle="None", marker=".")
axs[0].plot(t_data, y_data[:, 0], label="data S", linestyle="None", marker="x")
axs[0].set_title(f"S (Rel. Error: {rel_S:.2e})")
axs[0].legend()

axs[1].plot(exact_ts, exact_ys[:, 1], label="True I")
axs[1].plot(exact_ts, model_ys[:, 1], label="Pred I", linestyle="--")
# axs[1].plot(t_ge, y_ge[:, 1], label="ge I", linestyle="None", marker=".")
axs[1].plot(t_data, y_data[:, 1], label="data S", linestyle="None", marker="x")
axs[1].set_title(f"I (Rel. Error: {rel_I:.2e})")
axs[1].legend()

axs[2].plot(loss_list)
axs[2].set_yscale("log")
axs[2].set_title("Training Loss")
# Out:
# Text(0.5, 1.0, 'Training Loss')

# %%
print(f'alpha:{eval_alpha}')

beta_list=vmap(lambda t: model.beta(jnp.array([t])))(exact_ts)
beta_list=jnp.squeeze(beta_list)

def beta(t):
    beta = lambda t: 0.025 * jnp.sin(2 * jnp.pi * t / 20) + 0.03
    return beta(t)

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# alpha 변화 그래프
axs[0].plot(alpha_list)
axs[0].axhline(0.2, color='red', linestyle='--', label="True Alpha")
axs[0].set_title("Alpha over Epochs")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Alpha")

# beta 변화 그래프
axs[1].plot(exact_ts, beta_list)
axs[1].plot(exact_ts, beta(exact_ts), color='red', linestyle='--', label="True beta")
axs[1].set_title("Beta over Epochs")
axs[1].set_xlabel("time")
axs[1].set_ylabel("Beta")

plt.tight_layout()
plt.show()
# Out:
# alpha:0.19761894643306732
